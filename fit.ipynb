# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import

# %%
df = pd.read_table("./He_totalCS.txt", names=["energy", "CS"], sep="    ", skiprows=1, engine="python")

# %%
plt.plot(df.energy, df.CS, "o")
#plt.yscale("log")
plt.xlim(1.0, 20.0)
plt.ylim(180, 1000)
# Out:
# (180.0, 1000.0)
